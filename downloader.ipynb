# %%
import yfinance as yf
import pandas as pd

tickers = {
    "MA": "MA",
    "V": "V"
}

for ticker, name in tickers.items():
    data = yf.download(
        ticker,
        period="max",
        interval="1d",
        auto_adjust=False,
        progress=False
    )

    filename = f"{name}_daily.csv"
    data.to_csv(filename, header=True)

    print(f"{ticker} data saved to {filename}")
# Out:
# MA data saved to MA_daily.csv
# V data saved to V_daily.csv
